# %%
number = int(input("Enter your number: "))

a_0 = "zero"
a_1 = "one"
a_2 = "two"
a_3 = "three"
a_4 = "four"
a_5 = "five"
a_6 = "six"
a_7 = "seven"
a_8 = "eight"
a_9 = "nine"
a_10 = "ten"
a_11 = "eleven"
a_12 = "twelve"
a_13 = "thirteen"
a_14 = "fourteen"
a_15 = "fifteen"
a_16 = "sixteen"
a_17 = "seventeen"
a_18 = "eighteen"
a_19 = "nineteen"
a_20 = "twenty"
a_21 = ("twenty " + a_1)
a_22 = ("twenty " + a_2)
a_23 = ("twenty " + a_3)
a_24 = ("twenty " + a_4)
a_25 = ("twenty " + a_5)
a_26 = ("twenty " + a_6)
a_27 = ("twenty " + a_7)
a_28 = ("twenty " + a_8)
a_29 = ("twenty " + a_9)
a_30 = "thirty"
a_31 = "thirty one"
neg = "negative "

if number == 0:
    print(a_0)
elif number == 1:
    print(a_1)
elif number == 2:
    print(a_2)
elif number == 3:
    print(a_3)
elif number == 4:
    print(a_4)
elif number == 5:
    print(a_5)
elif number == 6:
    print(a_6)
elif number == 7:
    print(a_7)
elif number == 8:
    print(a_8)
elif number == 9:
    print(a_9)
elif number == 10:
    print(a_10)
elif number == 11:
    print(a_11)
elif number == 12:
    print(a_12)
elif number == 13:
    print(a_13)
elif number == 14:
    print(a_14)
elif number == 15:
    print(a_15)
elif number == 16:
    print(a_16)
elif number == 17:
    print(a_17)
elif number == 18:
    print(a_18)
elif number == 19:
    print(a_19)
elif number == 20:
    print(a_20)
elif number == 21:
    print(a_21)
elif number == 22:
    print(a_22)
elif number == 23:
    print(a_23)
elif number == 24:
    print(a_24)
elif number == 25:
    print(a_25)
elif number == 26:
    print(a_26)
elif number == 27:
    print(a_27)
elif number == 28:
    print(a_28)
elif number == 29:
    print(a_29)
elif number == 30:
    print(a_30)
elif number == -1:
    print(neg + a_1)
elif number == -2:
    print(neg + a_2)
elif number == -3:
    print(neg + a_3)
elif number == -4:
    print(neg + a_4)
elif number == -5:
    print(neg + a_5)
elif number == -6:
    print(neg + a_6)
elif number == -7:
    print(neg + a_7)
elif number == -8:
    print(neg + a_8)
elif number == -9:
    print(neg + a_9)
elif number == -10:
    print(neg + a_10)
elif number == -11:
    print(neg + a_11)
elif number == -12:
    print(neg + a_12)
elif number == -13:
    print(neg + a_13)
elif number == -14:
    print(neg + a_14)
elif number == -15:
    print(neg + a_15)
elif number == -16:
    print(neg + a_16)
elif number == -17:
    print(neg + a_17)
elif number == -18:
    print(neg + a_18)
elif number == -19:
    print(neg + a_19)
elif number == -20:
    print(neg + a_20)
elif number == -21:
    print(neg + a_21)
elif number == -22:
    print(neg + a_22)
elif number == -23:
    print(neg + a_23)
elif number == -24:
    print(neg + a_24)
elif number == -25:
    print(neg + a_25)
elif number == -26:
    print(neg + a_26)
elif number == -27:
    print(neg + a_27)
elif number == -28:
    print(neg + a_28)
elif number == -29:
    print(neg + a_29)
elif number == -30:
    print(neg + a_30)
elif number < -30 or number > 30:
    print("Numbers below -30 and above 30 are not supported, please try again.")
